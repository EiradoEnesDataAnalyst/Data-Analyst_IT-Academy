# %%
# Check codebook

import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None) 

owid_codebook = pd.read_csv(r"C:\Users\eirad\Desktop\IT ACADEMY\Sprint_13_Proyecto_Final\data\owid-energy-codebook.csv")

owid_codebook.head()
# Out:
#        column                         title  \
# 0     country                       Country
# 1        year                          Year
# 2    iso_code                      ISO code
# 3  population                    Population
# 4         gdp  Gross domestic product (GDP)
#
#                                                                                                                                      description  \
# 0                                                                                                                           Geographic location.
# 1                                                                                                                           Year of observation.
# 2                                                                                                 ISO 3166-1 alpha-3 three-letter country codes.
# ...

# %%
gdp = owid_codebook[owid_codebook["column"].str.contains("gdp", case=False)]
gdp
# Out:
#             column                               title  \
# 4              gdp        Gross domestic product (GDP)
# 33  energy_per_gdp  Primary energy consumption per GDP
#
#                                                                                                                                       description  \
# 4   Total economic output of a country or region per year. This data is adjusted for inflation and differences in living costs between countries.
# 33                                                                                                Measured in kilowatt-hours per international-$.
#
#                                   unit  \
# 4   international-$ in 2011 prices ($)
# 33          kilowatt-hours per $ (kWh)
#
# ...

# %%
# consumption

consumption = owid_codebook[owid_codebook["column"].str.contains("consumption", case=False)]
consumption
# Out:
#                           column  \
# 8            biofuel_consumption
# 17              coal_consumption
# 39       fossil_fuel_consumption
# 44               gas_consumption
# 57             hydro_consumption
# 65        low_carbon_consumption
# 75           nuclear_consumption
# 83               oil_consumption
# 93   other_renewable_consumption
# 105   primary_energy_consumption
# 108       renewables_consumption
# 116            solar_consumption
# 124             wind_consumption
#
#                                                   title  \
# 8              Primary energy consumption from biofuels
# 17                 Primary energy consumption from coal
# 39         Primary energy consumption from fossil fuels
# 44                  Primary energy consumption from gas
# 57           Primary energy consumption from hydropower
# 65   Primary energy consumption from low-carbon sources
# 75        Primary energy consumption from nuclear power
# ...

# %%
share_energy = owid_codebook[owid_codebook["column"].str.contains("share_energy",case=False)]
share_energy
# Out:
#                             column  \
# 12            biofuel_share_energy
# 25               coal_share_energy
# 29        electricity_share_energy
# 41             fossil_share_energy
# 53                gas_share_energy
# 62              hydro_share_energy
# 70         low_carbon_share_energy
# 80            nuclear_share_energy
# 92                oil_share_energy
# 103  other_renewables_share_energy
# 113        renewables_share_energy
# 121             solar_share_energy
# 129              wind_share_energy
#
#                                                                       title  \
# 12             Share of primary energy consumption that comes from biofuels
# 25                 Share of primary energy consumption that comes from coal
# 29                  Total electricity generation as share of primary energy
# 41         Share of primary energy consumption that comes from fossil fuels
# 53                  Share of primary energy consumption that comes from gas
# ...

# %%
#

share_energy = owid_codebook[owid_codebook["column"].str.contains("emis",case=False)]
share_energy
# Out:
#                       column                                            title  \
# 54  greenhouse_gas_emissions  Lifecycle emissions from electricity generation
#
#                                    description  \
# 54  Measured in megatonnes of CO₂ equivalents.
#
#                                    unit  \
# 54  million tonnes CO₂ equivalents (Mt)
#
#                                                                                                                                                                                                      source
# 54  Ember - Yearly Electricity Data Europe (2026) [https://ember-energy.org/data/yearly-electricity-data/]; Ember - Yearly Electricity Data (2026) [https://ember-energy.org/data/yearly-electricity-data/]
